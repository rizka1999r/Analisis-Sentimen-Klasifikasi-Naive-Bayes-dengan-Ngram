# %%
import numpy as np # linear algebra
import pandas as pd 
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS

#mpl.rcParams['figure.figsize']=(8.0,6.0)    #(6.0,4.0)
mpl.rcParams['font.size']=12                #10 
mpl.rcParams['savefig.dpi']=100             #72 
mpl.rcParams['figure.subplot.bottom']=.1 


stopwords = set(STOPWORDS)
data = pd.read_csv("labeling1.csv")
data.head(5)
# Out:
#                  created_at  \
# 0  2022-04-23T23:15:31.000Z
# 1  2022-04-23T22:54:40.000Z
# 2  2022-04-23T22:41:21.000Z
# 3  2022-04-23T21:29:50.000Z
# 4  2022-04-23T21:16:39.000Z
#
#                                           text_clean  \
# 0  zelensky kembali menyerukan untuk pertemuan de...
# 1  zelenskyy berjanji lawan invasi rusia  nhk wor...
# 2  bbm naik dampak invasi rusia ke ukraina budi m...
# 3  tidak aktif  bulan yang lalu terakhir baru upl...
# 4  invasi rusia ke ukraina dimulai tanggal  febru...
#
#                                    text_preprocessed  polarity  polarity_score
# 0  zelensky kembali seru untuk temu dengan putin ...  negative       -0.752306
# 1  zelenskyy janji lawan invasi rusia nhk worldja...  negative       -0.815056
# 2  bbm naik dampak invasi rusia ke ukraina budi m...  negative       -1.848306
# 3  tidak aktif bulan yang lalu akhir baru upload ...  negative       -1.821722
# 4  invasi rusia ke ukraina mulai tanggal februari...  negative       -2.817861

# %%
# data = data[data["polarity"].isin(["neutral"])]
data[(data["polarity"] == "neutral")]
# Out:
#                      created_at  \
# 12     2022-04-23T16:51:12.000Z
# 31     2022-04-23T12:05:05.000Z
# 55     2022-04-23T05:48:29.000Z
# 69     2022-04-22T22:12:14.000Z
# 99     2022-04-22T08:26:00.000Z
# ...                         ...
# 17804  2022-03-22T02:59:01.000Z
# 17823  2022-03-22T00:00:02.000Z
# 17834  2022-03-21T19:56:15.000Z
# 17839  2022-03-21T17:26:05.000Z
# 17854  2022-03-21T14:27:35.000Z
#
#                                               text_clean  \
# 12                       dampak sanksi yang paling serem
# 31     greenpeace selaku organisasi swadaya masyaraka...
# 55     pm inggris boris johnson mengingatkan tidak ak...
# 69     banyak yang mengidolakan sosok presiden vladim...
# 99     tentara ukraina sedang dilatih di inggris untu...
# ...                                                  ...
# 17804  di pasar komoditas harga minyak mentah naik ta...
# 17823  russia n palestina keteteran perangnya indones...
# 17834  survei membuktikan wargaindonesia dukung invas...
# 17839  pihak berwenang ukraina mengatakan kebocoran a...
# 17854  uni eropa berencana meninggalkan pasokan minya...
#
#                                        text_preprocessed polarity  \
# 12                         dampak sanksi yang paling rem  neutral
# 31     greenpeace selaku organisasi swadaya masyaraka...  neutral
# 55     pm inggris bor johnson ingat tidak akan ada ak...  neutral
# 69     banyak yang idola sosok presiden vladimir puti...  neutral
# 99     tentara ukraina sedang latih di inggris untuk ...  neutral
# ...                                                  ...      ...
# 17804  di pasar komoditas harga minyak mentah naik ta...  neutral
# 17823  russia dan palestina keteter perang indonesia ...  neutral
# 17834  survei bukti wargaindonesia dukung invasi rusi...  neutral
# 17839  pihak wenang ukraina kata bocor amonia jadi pa...  neutral
# 17854  uni eropa rencana tinggal pasok minyak dan gas...  neutral
#
#        polarity_score
# 12           0.257944
# 31           0.158139
# 55           0.689389
# 69           0.993750
# 99           0.069667
# ...               ...
# 17804        0.061917
# 17823        0.543056
# 17834        0.227306
# 17839        0.029806
# 17854        0.436083
#
# [1429 rows x 5 columns]

# %%
wordcloud = WordCloud(
                          stopwords=stopwords,
                          max_words=70,
                          max_font_size=60, 
                          random_state=0
                         ).generate(str(data['text_preprocessed']))

print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("Kata Sering Muncul.png", dpi=900)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x0000020AA2BC6A10>
